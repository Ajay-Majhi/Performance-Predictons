# %% [markdown]
# # Student Performance Data Ingestion

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip
# Out:
# --2022-08-26 19:02:54--  https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20478 (20K) [application/x-httpd-php]
# Saving to: ‘student.zip’
#
# student.zip         100%[===================>]  20.00K  --.-KB/s    in 0.07s
#
# 2022-08-26 19:02:54 (295 KB/s) - ‘student.zip’ saved [20478/20478]

# %%
# !mkdir data
# !unzip student.zip -d data
# Out:
# Archive:  student.zip
#   inflating: data/student-mat.csv
#   inflating: data/student-por.csv
#   inflating: data/student-merge.R
#   inflating: data/student.txt

# %%
# !rm -f student.zip
